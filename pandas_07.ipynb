# %% [markdown]
# <a href="https://colab.research.google.com/github/atulnath/Pandas-100-days-challenge/blob/main/pandas_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Creating a sample student dataset
data = {
    'Name': ['Atul', 'Ajay', 'Arafat', 'Dhanush', 'Karim'],
    'Age': [18, 19, 17, 18, 20],
    'Grade': [85, 92, 78, 95, 88],
    'Subject': ['Math', 'Science', 'English', 'History', 'Math']
}

# Creating the DataFrame
df = pd.DataFrame(data)

# %%
df['Age'].astype(str)
# Out:
# 0    18
# 1    19
# 2    17
# 3    18
# 4    20
# Name: Age, dtype: object

# %%
df.describe()
# Out:
#              Age      Grade
# count   5.000000   5.000000
# mean   18.400000  87.600000
# std     1.140175   6.580274
# min    17.000000  78.000000
# 25%    18.000000  85.000000
# 50%    18.000000  88.000000
# 75%    19.000000  92.000000
# max    20.000000  95.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Age      5 non-null      int64
#  2   Grade    5 non-null      int64
#  3   Subject  5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df['Age'] = df['Age'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Age      5 non-null      object
#  2   Grade    5 non-null      int64
#  3   Subject  5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 292.0+ bytes

# %%
df['Name'].unique()
# Out:
# array(['Atul', 'Ajay', 'Arafat', 'Dhanush', 'Karim'], dtype=object)

# %%
df['Name'].replace('Ajay', 'Atul')
# Out:
# 0       Atul
# 1       Atul
# 2     Arafat
# 3    Dhanush
# 4      Karim
# Name: Name, dtype: object

# %%
df
# Out:
#       Name Age  Grade  Subject
# 0     Atul  18     85     Math
# 1     Atul  19     92  Science
# 2   Arafat  17     78  English
# 3  Dhanush  18     95  History
# 4    Karim  20     88     Math

# %%
df['Name'].unique() # Only shows unique values
# Out:
# array(['Atul', 'Arafat', 'Dhanush', 'Karim'], dtype=object)

# %%
df.loc[1, 'Name'] = 'Ajay'

# %%
df
# Out:
#       Name Age  Grade  Subject
# 0     Atul  18     85     Math
# 1     Ajay  19     92  Science
# 2   Arafat  17     78  English
# 3  Dhanush  18     95  History
# 4    Karim  20     88     Math

# %%
list_of_unique_names = df['Name'].nunique()

list_of_unique_names
# Out:
# 5

# %%
list_of_unique_age = df['Age'].nunique() # Here it counts how many unique values

list_of_unique_age
# Out:
# 4

# %%
list_of_unique_age = df['Age'].unique() # Here is shows list of unique values

list_of_unique_age
# Out:
# array(['18', '19', '17', '20'], dtype=object)

# %%
list_of_values_in_Name = df['Name'].value_counts()

list_of_values_in_Name
# Out:
# Name
# Atul       1
# Ajay       1
# Arafat     1
# Dhanush    1
# Karim      1
# Name: count, dtype: int64

# %%
list_of_values_in_age = df['Age'].value_counts()

list_of_values_in_age
# Out:
# Age
# 18    2
# 19    1
# 17    1
# 20    1
# Name: count, dtype: int64

# %%
df.groupby('Name')['Grade'].mean()
# Out:
# Name
# Ajay       92.0
# Arafat     78.0
# Atul       85.0
# Dhanush    95.0
# Karim      88.0
# Name: Grade, dtype: float64

# %%
df.groupby('Age')['Grade'].mean()
# Out:
# Age
# 17    78.0
# 18    90.0
# 19    92.0
# 20    88.0
# Name: Grade, dtype: float64

# %%
df.agg({'Grade': ['mean', 'max', 'min']})
# Out:
#       Grade
# mean   87.6
# max    95.0
# min    78.0

# %%
df.agg({'Grade': ['max', 'min', 'mean']})
# Out:
#       Grade
# max    95.0
# min    78.0
# mean   87.6

# %%
other = pd.DataFrame({'Name':['Atul'], 'Grade': ['A']}) # Create new dataframe
# other has two column, 'Name' and 'Grade'
pd.merge(df, other, on='Name') # Combine both dataframe based on common col Name
# Out:
#    Name Age  Grade_x Subject Grade_y
# 0  Atul  18       85    Math       A

# %%
df
# Out:
#       Name Age  Grade  Subject
# 0     Atul  18     85     Math
# 1     Ajay  19     92  Science
# 2   Arafat  17     78  English
# 3  Dhanush  18     95  History
# 4    Karim  20     88     Math

# %%
df2 = pd.DataFrame({'Name':'Rahim', 'Age':[29]})

pd.concat([df, df2], ignore_index=True)
# Out:
#       Name Age  Grade  Subject
# 0     Atul  18   85.0     Math
# 1     Ajay  19   92.0  Science
# 2   Arafat  17   78.0  English
# 3  Dhanush  18   95.0  History
# 4    Karim  20   88.0     Math
# 5    Rahim  29    NaN      NaN

# %%
employee = {
    'Name':['Atul','Ajay','Dhanush'],
    'Depearmet':['ASE', 'MNS','ASE'],
    'Salary':[20000, 30000, 25000]
}
# We will see Salary of different employee based on their department
df_employee = pd.DataFrame(employee)
pd.pivot_table(df_employee, index='Name', values='Salary', columns='Depearmet')
# Out:
# Depearmet      ASE      MNS
# Name
# Ajay           NaN  30000.0
# Atul       20000.0      NaN
# Dhanush    25000.0      NaN
